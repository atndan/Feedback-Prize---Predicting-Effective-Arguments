# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import cv2
import os, random

# %% [markdown]
# **Train Data**

# %%
df = pd.read_csv('../input/hubmap-organ-segmentation/train.csv')
df.head()

# %%
df.info()

# %%
df['organ'].value_counts()

# %% [markdown]
# **Test Data**

# %%
test = pd.read_csv('../input/hubmap-organ-segmentation/test.csv')
test.head()

# %% [markdown]
# **sample_submission**

# %%
submision_sample = pd.read_csv('../input/hubmap-organ-segmentation/sample_submission.csv')
submision_sample.head()

# %% [markdown]
# **Train Images**

# %%
fig = plt.figure(figsize=(12,8))
i = 0
c=1
for dirname, _ , filenames in os.walk('../input/hubmap-organ-segmentation/train_images'):
    for filename in filenames:
        while i < 5:
            img = cv2.imread(os.path.join(dirname,filename))
            plt.subplot(3, 2, c)
            plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB));plt.axis("off");
            i += 1
            c += 1

# %% [markdown]
# **Target Image**

# %%
img = cv2.imread('../input/hubmap-organ-segmentation/test_images/10078.tiff')
plt.figure(figsize=(9,9))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)); plt.axis("off");

# %%
np.zeros(2*3)
